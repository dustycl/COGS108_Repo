# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_excel('food_access.xls', sheet_name = None)
access = df['ACCESS']
access = access[['FIPS', 'State', 'County', 'LACCESS_POP15']]
access
# Out:
#        FIPS State       County  LACCESS_POP15
# 0      1001    AL      Autauga   17496.693038
# 1      1003    AL      Baldwin   30561.264430
# 2      1005    AL      Barbour    6069.523628
# 3      1007    AL         Bibb     969.378841
# 4      1009    AL       Blount    3724.428242
# 5      1011    AL      Bullock    4141.900365
# 6      1013    AL       Butler    1304.328756
# 7      1015    AL      Calhoun   27785.986765
# 8      1017    AL     Chambers    7131.505717
# 9      1019    AL     Cherokee     103.522499
# 10     1021    AL      Chilton    1469.899110
# 11     1023    AL      Choctaw    2702.895199
# 12     1025    AL       Clarke    5712.926332
# 13     1027    AL         Clay     642.740920
# 14     1029    AL     Cleburne     789.535143
# 15     1031    AL       Coffee   10486.085980
# 16     1033    AL      Colbert   11095.666304
# 17     1035    AL      Conecuh    3558.359440
# 18     1037    AL        Coosa    2828.930334
# ...

# %%
stores = df['STORES']
stores = stores[['FIPS', 'State', 'County', 'GROC14']]
stores
# Out:
#        FIPS State       County  GROC14
# 0      1001    AL      Autauga       4
# 1      1003    AL      Baldwin      29
# 2      1005    AL      Barbour       5
# 3      1007    AL         Bibb       5
# 4      1009    AL       Blount       6
# 5      1011    AL      Bullock       2
# 6      1013    AL       Butler       3
# 7      1015    AL      Calhoun      27
# 8      1017    AL     Chambers       7
# 9      1019    AL     Cherokee       5
# 10     1021    AL      Chilton       6
# 11     1023    AL      Choctaw       3
# 12     1025    AL       Clarke       5
# 13     1027    AL         Clay       3
# 14     1029    AL     Cleburne       2
# 15     1031    AL       Coffee       5
# 16     1033    AL      Colbert      10
# 17     1035    AL      Conecuh       2
# 18     1037    AL        Coosa       1
# 19     1039    AL    Covington       6
# 20     1041    AL     Crenshaw       3
# 21     1043    AL      Cullman      15
# 22     1045    AL         Dale       8
# ...

# %%
restaurants = df['RESTAURANTS']
restaurants = restaurants[['FIPS', 'State', 'County', 'FFR14', 'FSR14']]
restaurants
# Out:
#        FIPS State       County  FFR14  FSR14
# 0      1001    AL      Autauga     36     29
# 1      1003    AL      Baldwin    132    221
# 2      1005    AL      Barbour     22     15
# 3      1007    AL         Bibb      5      5
# 4      1009    AL       Blount     21     15
# 5      1011    AL      Bullock      3      1
# 6      1013    AL       Butler     17     10
# 7      1015    AL      Calhoun    103     77
# 8      1017    AL     Chambers     26     16
# 9      1019    AL     Cherokee     15     11
# 10     1021    AL      Chilton     20     18
# 11     1023    AL      Choctaw      6      5
# 12     1025    AL       Clarke     26     15
# 13     1027    AL         Clay      4      6
# 14     1029    AL     Cleburne      8      2
# 15     1031    AL       Coffee     34     28
# 16     1033    AL      Colbert     52     38
# 17     1035    AL      Conecuh      7      4
# 18     1037    AL        Coosa      1      0
# 19     1039    AL    Covington     24     18
# ...

# %%
local = df['LOCAL']
local = local[['FIPS', 'State', 'County', 'FMRKT16']]
local
# Out:
#        FIPS State       County  FMRKT16
# 0      1001    AL      Autauga        1
# 1      1003    AL      Baldwin        4
# 2      1005    AL      Barbour        4
# 3      1007    AL         Bibb        1
# 4      1009    AL       Blount        1
# 5      1011    AL      Bullock        1
# 6      1013    AL       Butler        2
# 7      1015    AL      Calhoun        2
# 8      1017    AL     Chambers        1
# 9      1019    AL     Cherokee        1
# 10     1021    AL      Chilton        0
# 11     1023    AL      Choctaw        1
# 12     1025    AL       Clarke        2
# 13     1027    AL         Clay        2
# 14     1029    AL     Cleburne        1
# 15     1031    AL       Coffee        1
# 16     1033    AL      Colbert        3
# 17     1035    AL      Conecuh        1
# 18     1037    AL        Coosa        0
# 19     1039    AL    Covington        2
# 20     1041    AL     Crenshaw        1
# 21     1043    AL      Cullman        1
# ...

# %%
health = df['HEALTH']
health = health[['FIPS', 'State', 'County', 'PCT_DIABETES_ADULTS13', 'PCT_OBESE_ADULTS13']]
health
# Out:
#        FIPS State       County  PCT_DIABETES_ADULTS13  PCT_OBESE_ADULTS13
# 0      1001    AL      Autauga                   13.0                34.1
# 1      1003    AL      Baldwin                   10.4                27.4
# 2      1005    AL      Barbour                   18.4                44.4
# 3      1007    AL         Bibb                   14.8                40.3
# 4      1009    AL       Blount                   14.1                34.6
# 5      1011    AL      Bullock                   19.6                43.0
# 6      1013    AL       Butler                   17.7                36.3
# 7      1015    AL      Calhoun                   14.9                32.2
# 8      1017    AL     Chambers                   16.4                39.7
# 9      1019    AL     Cherokee                   13.3                33.6
# 10     1021    AL      Chilton                   13.3                35.9
# 11     1023    AL      Choctaw                   18.1                40.8
# ...

# %%
socio_economic = df['SOCIOECONOMIC']
socio_economic = socio_economic[['FIPS', 'State', 'County', 'MEDHHINC15', 'POVRATE15']]
socio_economic
# Out:
#        FIPS State       County  MEDHHINC15  POVRATE15
# 0      1001    AL      Autauga     56580.0       12.7
# 1      1003    AL      Baldwin     52387.0       12.9
# 2      1005    AL      Barbour     31433.0       32.0
# 3      1007    AL         Bibb     40767.0       22.2
# 4      1009    AL       Blount     50487.0       14.7
# 5      1011    AL      Bullock     28251.0       39.6
# 6      1013    AL       Butler     33868.0       25.8
# 7      1015    AL      Calhoun     42091.0       20.0
# 8      1017    AL     Chambers     35560.0       22.4
# 9      1019    AL     Cherokee     39144.0       19.4
# 10     1021    AL      Chilton     42767.0       20.2
# 11     1023    AL      Choctaw     35089.0       24.4
# 12     1025    AL       Clarke     37317.0       22.2
# 13     1027    AL         Clay     38908.0       18.4
# 14     1029    AL     Cleburne     42136.0       18.9
# 15     1031    AL       Coffee     46858.0       16.2
# ...

# %%
access = access.merge(stores, on=["FIPS", "State", "County"], how="outer")
access
# Out:
#        FIPS State       County  LACCESS_POP15  GROC14
# 0      1001    AL      Autauga   17496.693038       4
# 1      1003    AL      Baldwin   30561.264430      29
# 2      1005    AL      Barbour    6069.523628       5
# 3      1007    AL         Bibb     969.378841       5
# 4      1009    AL       Blount    3724.428242       6
# 5      1011    AL      Bullock    4141.900365       2
# 6      1013    AL       Butler    1304.328756       3
# 7      1015    AL      Calhoun   27785.986765      27
# 8      1017    AL     Chambers    7131.505717       7
# 9      1019    AL     Cherokee     103.522499       5
# 10     1021    AL      Chilton    1469.899110       6
# 11     1023    AL      Choctaw    2702.895199       3
# 12     1025    AL       Clarke    5712.926332       5
# 13     1027    AL         Clay     642.740920       3
# 14     1029    AL     Cleburne     789.535143       2
# 15     1031    AL       Coffee   10486.085980       5
# ...

# %%
access = access.merge(restaurants, on=["FIPS", "State", "County"], how="outer")
access
# Out:
#        FIPS State       County  LACCESS_POP15  GROC14  FFR14  FSR14
# 0      1001    AL      Autauga   17496.693038       4     36     29
# 1      1003    AL      Baldwin   30561.264430      29    132    221
# 2      1005    AL      Barbour    6069.523628       5     22     15
# 3      1007    AL         Bibb     969.378841       5      5      5
# 4      1009    AL       Blount    3724.428242       6     21     15
# 5      1011    AL      Bullock    4141.900365       2      3      1
# 6      1013    AL       Butler    1304.328756       3     17     10
# 7      1015    AL      Calhoun   27785.986765      27    103     77
# 8      1017    AL     Chambers    7131.505717       7     26     16
# 9      1019    AL     Cherokee     103.522499       5     15     11
# 10     1021    AL      Chilton    1469.899110       6     20     18
# 11     1023    AL      Choctaw    2702.895199       3      6      5
# 12     1025    AL       Clarke    5712.926332       5     26     15
# ...

# %%
access = access.merge(local, on=["FIPS", "State", "County"], how="outer")
access
# Out:
#        FIPS State       County  LACCESS_POP15  GROC14  FFR14  FSR14  FMRKT16
# 0      1001    AL      Autauga   17496.693038       4     36     29        1
# 1      1003    AL      Baldwin   30561.264430      29    132    221        4
# 2      1005    AL      Barbour    6069.523628       5     22     15        4
# 3      1007    AL         Bibb     969.378841       5      5      5        1
# 4      1009    AL       Blount    3724.428242       6     21     15        1
# 5      1011    AL      Bullock    4141.900365       2      3      1        1
# 6      1013    AL       Butler    1304.328756       3     17     10        2
# 7      1015    AL      Calhoun   27785.986765      27    103     77        2
# 8      1017    AL     Chambers    7131.505717       7     26     16        1
# 9      1019    AL     Cherokee     103.522499       5     15     11        1
# 10     1021    AL      Chilton    1469.899110       6     20     18        0
# ...

# %%
access = access.merge(health, on=["FIPS", "State", "County"], how="outer")
access
# Out:
#        FIPS State       County  LACCESS_POP15  GROC14  FFR14  FSR14  FMRKT16  \
# 0      1001    AL      Autauga   17496.693038       4     36     29        1
# 1      1003    AL      Baldwin   30561.264430      29    132    221        4
# 2      1005    AL      Barbour    6069.523628       5     22     15        4
# 3      1007    AL         Bibb     969.378841       5      5      5        1
# 4      1009    AL       Blount    3724.428242       6     21     15        1
# 5      1011    AL      Bullock    4141.900365       2      3      1        1
# 6      1013    AL       Butler    1304.328756       3     17     10        2
# 7      1015    AL      Calhoun   27785.986765      27    103     77        2
# 8      1017    AL     Chambers    7131.505717       7     26     16        1
# 9      1019    AL     Cherokee     103.522499       5     15     11        1
# 10     1021    AL      Chilton    1469.899110       6     20     18        0
# ...

# %%
access = access.merge(socio_economic, on=["FIPS", "State", "County"], how="outer")
access
# Out:
#        FIPS State       County  LACCESS_POP15  GROC14  FFR14  FSR14  FMRKT16  \
# 0      1001    AL      Autauga   17496.693038       4     36     29        1
# 1      1003    AL      Baldwin   30561.264430      29    132    221        4
# 2      1005    AL      Barbour    6069.523628       5     22     15        4
# 3      1007    AL         Bibb     969.378841       5      5      5        1
# 4      1009    AL       Blount    3724.428242       6     21     15        1
# 5      1011    AL      Bullock    4141.900365       2      3      1        1
# 6      1013    AL       Butler    1304.328756       3     17     10        2
# 7      1015    AL      Calhoun   27785.986765      27    103     77        2
# 8      1017    AL     Chambers    7131.505717       7     26     16        1
# 9      1019    AL     Cherokee     103.522499       5     15     11        1
# 10     1021    AL      Chilton    1469.899110       6     20     18        0
# ...

# %%
access.isnull().any().sum()
# Out:
# 5

# %%
access.dropna(how="any", inplace=True)
access
# Out:
#        FIPS State       County  LACCESS_POP15  GROC14  FFR14  FSR14  FMRKT16  \
# 0      1001    AL      Autauga   17496.693038       4     36     29        1
# 1      1003    AL      Baldwin   30561.264430      29    132    221        4
# 2      1005    AL      Barbour    6069.523628       5     22     15        4
# 3      1007    AL         Bibb     969.378841       5      5      5        1
# 4      1009    AL       Blount    3724.428242       6     21     15        1
# 5      1011    AL      Bullock    4141.900365       2      3      1        1
# 6      1013    AL       Butler    1304.328756       3     17     10        2
# 7      1015    AL      Calhoun   27785.986765      27    103     77        2
# 8      1017    AL     Chambers    7131.505717       7     26     16        1
# 9      1019    AL     Cherokee     103.522499       5     15     11        1
# 10     1021    AL      Chilton    1469.899110       6     20     18        0
# ...

# %%
access.describe()
# Out:
#                FIPS  LACCESS_POP15       GROC14        FFR14        FSR14  \
# count   3120.000000    3120.000000  3120.000000  3120.000000  3120.000000
# mean   30364.400000   19307.368121    21.107372    73.194551    76.475321
# std    15154.475947   47830.775929    90.684955   255.601242   259.569327
# min     1001.000000       0.000000     0.000000     0.000000     0.000000
# 25%    18178.500000    1632.491143     3.000000     5.000000     7.000000
# 50%    29176.000000    4131.174278     5.000000    15.000000    17.000000
# 75%    45073.500000   13174.899203    12.000000    44.000000    49.000000
# max    56045.000000  740267.412661  2429.000000  7798.000000  7821.000000
#
#            FMRKT16  PCT_DIABETES_ADULTS13  PCT_OBESE_ADULTS13     MEDHHINC15  \
# count  3120.000000            3120.000000         3120.000000    3120.000000
# mean      2.747756              11.230481           31.015224   48586.288462
# ...
